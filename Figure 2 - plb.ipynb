# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plorts
plt.style.use(['plorts', 'plorts-web'])

# %%
# df from https://apps.automeris.io/wpd/
df = pd.read_csv('./plb_figure_2.csv', header=None)
df = df.ffill(axis=1)
df
# Out:
#                      0                  1                    2   \
# 0             Dataset 0          Dataset 0            Dataset 1
# 1                     X                  Y                    X
# 2   0.14829400312303442  61.77381885927227  0.08024058545603263
# 3   0.25849728608686795  65.91537349676904  0.23026641758579425
# 4    0.4348756704834371  72.14163465435303   0.4247282728194328
# ..                  ...                ...                  ...
# 74                  NaN                NaN                  NaN
# 75                  NaN                NaN                  NaN
# 76                  NaN                NaN                  NaN
# 77                  NaN                NaN                  NaN
# 78                  NaN                NaN                  NaN
#
#                    3                    4                   5   \
# 0           Dataset 1            Dataset 2           Dataset 2
# 1                   Y                    X                   Y
# 2   73.83795626384895  0.06883131099918693   65.92521577859418
# 3   70.00259914677267   0.2588677110015938  63.125063639116185
# 4   65.15193080888204    0.384042147185639   58.77710783095248
# ..                ...                  ...                 ...
# 74                NaN                  NaN                 NaN
# 75                NaN                  NaN                 NaN
# 76                NaN                  NaN                 NaN
# 77                NaN                  NaN                 NaN
# 78                NaN                  NaN                 NaN
#
#                      6                   7                   8   \
# 0             Dataset 3           Dataset 3           Dataset 4
# 1                     X                   Y                   X
# 2   0.06837108610513387  58.963554017576826    0.09401419180907
# 3   0.32573020989513357   60.03179255899916  0.3940166798894378
# 4    0.5421770243534088  56.428988232543574  0.6686222104234902
# ..                  ...                 ...                 ...
# 74                  NaN                 NaN                 NaN
# 75                  NaN                 NaN                 NaN
# 76                  NaN                 NaN                 NaN
# 77                  NaN                 NaN                 NaN
# 78                  NaN                 NaN                 NaN
#
#                    9                    10                 11  \
# 0           Dataset 4            Dataset 5          Dataset 5
# 1                   Y                    X                  Y
# 2   53.51241902083956  0.08717015052746913  42.49625320618195
# 3   46.21213553258028  0.21959425129259502  46.10901352222871
# 4   42.50882010101624  0.31881480970138876  49.55315396800194
# ..                ...                  ...                ...
# 74                NaN   11.746546903964456  64.51997365890807
# 75                NaN   11.937613197479775  64.39032493875405
# 76                NaN   12.131435227860704  64.35928271862743
# 77                NaN   12.314163219128886    64.469328511476
# 78                NaN   12.527352111718109  64.55074035637084
#
#                      12                  13                  14  \
# 0             Dataset 6           Dataset 6           Dataset 7
# 1                     X                   Y                   X
# 2    0.1290618408837343  39.789885920114074    0.33406771035674
# 3   0.31187963213124426   39.22349295959225  0.8602170142338093
# 4    0.5611813823161462   38.41526717044438  1.0292437736561024
# ..                  ...                 ...                 ...
# 74    64.51997365890807   64.51997365890807   64.51997365890807
# 75    64.39032493875405   64.39032493875405   64.39032493875405
# 76    64.35928271862743   64.35928271862743   64.35928271862743
# 77      64.469328511476     64.469328511476     64.469328511476
# 78    64.55074035637084   64.55074035637084   64.55074035637084
#
#                     15
# 0            Dataset 7
# 1                    Y
# 2   38.941316933641886
# 3     38.3980474677969
# 4   41.602996484542615
# ..                 ...
# 74   64.51997365890807
# 75   64.39032493875405
# 76   64.35928271862743
# 77     64.469328511476
# 78   64.55074035637084
#
# [79 rows x 16 columns]

# %%
df.columns = [f"{axis}{dataset}" for axis, dataset in zip(df.iloc[1], df.iloc[0])]
df = df.drop([0,1])
# 75   64.39032493875405  75
# 76   64.35928271862743  76
# 77     64.469328511476  77
# 78   64.55074035637084  78
#
# [77 rows x 17 columns]

# %%
df = pd.wide_to_long(df, ['X', 'Y'], i="id", j="dataset", suffix='Dataset \d+').reset_index()

# %%
df['Y'] = df.Y.astype(float)
df['X'] = df.X.astype(float)

# %%
df = df.dropna()

# %%
plorts.plot(df, x='X', y='Y', hue='dataset')
plt.axis(xmin=0, xmax=20)
# Out:
# (0.0, 20.0, 34.038801445909975, 84.17336957320714)

# %%
df = df[['dataset', 'X', 'Y']]

# %%
combined_df = []
for time in df.X:
    for dataset in set(df.dataset):
        matches = df[(df.X == time) & (df.dataset == dataset)]
        if len(matches) == 0:
            combined_df.append(pd.DataFrame([{
                'X': time,
                'Y': None,
                'dataset': dataset
            }]))
        elif len(matches) == 1:
            combined_df.append(matches)
        else:
            print(matches)
combined_df = pd.concat(combined_df)

# %%
combined_df
# Out:
#              X          Y    dataset
# 0     0.148294        NaN  Dataset 1
# 0     0.148294        NaN  Dataset 7
# 0     0.148294        NaN  Dataset 5
# 0     0.148294  61.773819  Dataset 0
# 0     0.148294        NaN  Dataset 6
# ..         ...        ...        ...
# 0    64.550740        NaN  Dataset 0
# 538  64.550740  64.550740  Dataset 6
# 0    64.550740        NaN  Dataset 2
# 0    64.550740        NaN  Dataset 4
# 0    64.550740        NaN  Dataset 3
#
# [4008 rows x 3 columns]

# %%
def interp_nans(x, y):
    is_nan = np.isnan(y)
    res = y * 1.0
    res[is_nan] = np.interp(x[is_nan], x[-is_nan], y[-is_nan])
    return res

def interp(df, x, y):
    df = df.sort_values(x)
    df[y] = interp_nans(df[x], df[y])
    return df[[x,y]]

def stackplot(data, x, y, hue, cmap=palettes.neon):
    combined_df = []
    for x_val in df[x]:
        for h_val in set(df[hue]):
            matches = df[(df[x] == x_val) & (df[hue] == h_val)]
            if len(matches) == 0:
                combined_df.append(pd.DataFrame([{
                    x: x_val,
                    y: None,
                    hue: h_val
                }]))
            elif len(matches) == 1:
                combined_df.append(matches)
            else:
                print(matches)
    combined_df = pd.concat(combined_df)
    
    interpolated = combined_df.groupby(hue).apply(lambda df: interp(df, x, y)).reset_index()

    xs = np.array(interpolated[x])
    yss = []
    labels = []
    for k,grp in interpolated.groupby(hue):
        labels.append(k)
        grp_xs = grp[x].tolist()
        grp_ys = grp[y].tolist()
        ys = []
        for v in xs:
            if len(grp_xs) > 0 and grp_xs[0] == v:
                ys.append(grp_ys.pop(0))
                grp_xs.pop(0)
            else:
                if len(ys) == 0:
                    ys.append(0.)
                else:
                    ys.append(ys[-1])
        assert len(grp_xs) == 0
        assert len(grp_ys) == 0
        assert len(ys) == len(xs)
        yss.append(np.array(ys, dtype=float))

    if cmap is not None:
        colors = colors_from_hue(interpolated, hue, cmap)
    else:
        colors = None

    plt.stackplot(xs, *yss, labels=labels, colors=colors)

    plt.ylabel(y)
    plt.xlabel(x)
    plt.gca().autoscale(tight=True)
    plt.gca().margins(y=0.1)

# %%
stackplot(df, x='X', y='Y', hue='dataset')
plt.xlabel("Time")
plt.axis(xmin=0, xmax=12)
plt.xticks([])
plt.axvline(x=6.5, linestyle=":", color="grey")
plorts.style_axis()
